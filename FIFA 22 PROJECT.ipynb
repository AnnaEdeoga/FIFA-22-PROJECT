# %% [markdown]
# The dataset we're going to use is one containing FIFA Players 22. Before we begin with the activities for this project, let's do a little bit of exploration together.
# First run all the cells. As you run the cells, learn what each output is saying. Furthermore, you can see the visualizations to understand more about the FIFA 22 Players dataset.

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# Select all the rows and the first 5 columns from the dataframe and store them in the variable df_first_five_cols
# syntax=> data.iloc[rows, columns]

# %%
df = pd.read_csv("C:/Users/NEW USER/OneDrive/Desktop/players_fifa22.csv")
df
# Out:
#            ID               Name                      FullName  Age  Height  \
# 0      158023           L. Messi                  Lionel Messi   34     170
# 1      188545     R. Lewandowski            Robert Lewandowski   32     185
# 2       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro   36     187
# 3      231747          K. Mbappé                 Kylian Mbappé   22     182
# 4      200389           J. Oblak                     Jan Oblak   28     188
# ...       ...                ...                           ...  ...     ...
# 19255  262759           S. Black                 Stephen Black   19     180
# 19256  250978            Ma Zhen                       Zhen Ma   23     196
# 19257  261985         Yang Haoyu                    Haoyu Yang   20     183
# 19258  261977           He Siwei                      Siwei He   20     174
# 19259  261932      Chen Guoliang                 Guoliang Chen   22     186
#
# ...

# %%
df_first_five_cols = df.iloc[:, 0:5]
df_first_five_cols
# Out:
#            ID               Name                      FullName  Age  Height
# 0      158023           L. Messi                  Lionel Messi   34     170
# 1      188545     R. Lewandowski            Robert Lewandowski   32     185
# 2       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro   36     187
# 3      231747          K. Mbappé                 Kylian Mbappé   22     182
# 4      200389           J. Oblak                     Jan Oblak   28     188
# ...       ...                ...                           ...  ...     ...
# 19255  262759           S. Black                 Stephen Black   19     180
# 19256  250978            Ma Zhen                       Zhen Ma   23     196
# 19257  261985         Yang Haoyu                    Haoyu Yang   20     183
# 19258  261977           He Siwei                      Siwei He   20     174
# 19259  261932      Chen Guoliang                 Guoliang Chen   22     186
#
# [19260 rows x 5 columns]

# %% [markdown]
# Choose all rows and extract columns with indices 3, 6, 4, and 1 from the DataFrame,
# arranging them in the specified order. Store your selection in the variable df_order_cols.
# You can employ either .iloc or .loc for this task. This question builds upon the previous one,
# so consider experimenting with column indices.
#  syntax => Use slicing in df.iloc[rows,[column indices]] or use df.loc[df.columns[column indices]]

# %%
df_order_cols = df.iloc[:, [1, 3, 4, 6]]
df_order_cols
# Out:
#                     Name  Age  Height  \
# 0               L. Messi   34     170
# 1         R. Lewandowski   32     185
# 2      Cristiano Ronaldo   36     187
# 3              K. Mbappé   22     182
# 4               J. Oblak   28     188
# ...                  ...  ...     ...
# 19255           S. Black   19     180
# 19256            Ma Zhen   23     196
# 19257         Yang Haoyu   20     183
# 19258           He Siwei   20     174
# 19259      Chen Guoliang   22     186
#
#                                                PhotoUrl
# 0      https://cdn.sofifa.com/players/158/023/22_60.png
# 1      https://cdn.sofifa.com/players/188/545/22_60.png
# 2      https://cdn.sofifa.com/players/020/801/22_60.png
# 3      https://cdn.sofifa.com/players/231/747/22_60.png
# 4      https://cdn.sofifa.com/players/200/389/22_60.png
# ...                                                 ...
# 19255  https://cdn.sofifa.com/players/262/759/22_60.png
# ...

# %% [markdown]
# Filter out first 50 rows from the Column number 3,6,4,1 into the variable fifty_rows
# syntax=> df.iloc[rows, [column indices]]

# %%
fifty_rows = df.iloc[:50, [3,6,4,1]]
fifty_rows
# Out:
#     Age                                          PhotoUrl  Height  \
# 0    34  https://cdn.sofifa.com/players/158/023/22_60.png     170
# 1    32  https://cdn.sofifa.com/players/188/545/22_60.png     185
# 2    36  https://cdn.sofifa.com/players/020/801/22_60.png     187
# 3    22  https://cdn.sofifa.com/players/231/747/22_60.png     182
# 4    28  https://cdn.sofifa.com/players/200/389/22_60.png     188
# 5    30  https://cdn.sofifa.com/players/192/985/22_60.png     181
# 6    29  https://cdn.sofifa.com/players/190/871/22_60.png     175
# 7    30  https://cdn.sofifa.com/players/215/914/22_60.png     168
# 8    27  https://cdn.sofifa.com/players/202/126/22_60.png     188
# 9    29  https://cdn.sofifa.com/players/192/448/22_60.png     187
# 10   35  https://cdn.sofifa.com/players/167/495/22_60.png     193
# 11   28  https://cdn.sofifa.com/players/200/104/22_60.png     183
# 12   29  https://cdn.sofifa.com/players/200/145/22_60.png     185
# ...

# %% [markdown]
# Select all the rows and the Columns ['short_name','age','player_positions', 'overall', 'value_eur']
# from the dataframe store your selection in the variable named_cols
# NB: Whenever the names of columns are given always use df.loc[]. (Location indexer/Label Indexer)
# Whenever the indices are given for rows or columns always go for df.iloc[].
# (Integer locator. And be careful indices start from 0)
# syntax => df.loc[rows,[column names]]

# %%
named_cols = df.loc[:, ['Name', 'Age', 'Positions', 'Overall', 'ValueEUR']]
named_cols
# Out:
#                     Name  Age Positions  Overall   ValueEUR
# 0               L. Messi   34  RW,ST,CF       93   78000000
# 1         R. Lewandowski   32        ST       92  119500000
# 2      Cristiano Ronaldo   36     ST,LW       91   45000000
# 3              K. Mbappé   22     ST,LW       91  194000000
# 4               J. Oblak   28        GK       91  112000000
# ...                  ...  ...       ...      ...        ...
# 19255           S. Black   19        CB       48     100000
# 19256            Ma Zhen   23        GK       48      50000
# 19257         Yang Haoyu   20        CB       48      90000
# 19258           He Siwei   20        CB       48     100000
# 19259      Chen Guoliang   22        CB       48      70000
#
# [19260 rows x 5 columns]

# %% [markdown]
# Filter out the first 14 rows and the Columns ['short_name','age','player_positions', 'overall', 'value_eur']
# from the dataframe and store the result in the variable named_cols_rows
# syntax => df.loc[rows,[column names]]

# %%
named_cols_rows = df.loc[14:, ['Name', 'Age', 'Positions', 'Overall', 'ValueEUR']]
named_cols_rows
# Out:
#                 Name  Age Positions  Overall   ValueEUR
# 14       T. Courtois   29        GK       89   85500000
# 15           S. Mané   29        LW       89  101000000
# 16       V. van Dijk   29        CB       89   86000000
# 17     G. Donnarumma   22        GK       89  119500000
# 18          M. Salah   29        RW       89  101000000
# ...              ...  ...       ...      ...        ...
# 19255       S. Black   19        CB       48     100000
# 19256        Ma Zhen   23        GK       48      50000
# 19257     Yang Haoyu   20        CB       48      90000
# 19258       He Siwei   20        CB       48     100000
# 19259  Chen Guoliang   22        CB       48      70000
#
# [19246 rows x 5 columns]

# %% [markdown]
# # Activities for df.loc, df.query with Conditioning (| or, & and, Not ~)

# %% [markdown]
# Find out how many players of overall rating greater than 90 exist in the dataset?
# #use df.loc[] and conditional selection to find all overall > 90 then sum them.
# Or use df.query('condition') and count the rows

# %%
greater_than_90_rating = df['Overall'] > 90
greater_than_90_rating.sum()
# Out:
# 7

# %% [markdown]
# Find out how many players with a value_eur of less than or equal to 20,000 exist in the dataset
# #Use the condition of <= 20000 on the column value_eur and then sum (( or count the rows))

# %%
less_than_20000_valueEur = df['ValueEUR'] <= 20000
less_than_20000_valueEur.sum()
#less_than_20000_valueEur = df.loc[df['ValueEUR'] <= 20000].count()
#less_than_20000_valueEur #.sum()
# Out:
# 98

# %% [markdown]
# Select the long_name and age of the players having the club_name='Manchester City'
# and store your selection in the variable name long_name_age
# #using conditioning on club_name and then project the columns ['long_name','age'] from
# the resulting DataFrame, easy when you try with .query method
# syntax => df.query(expr, inplace= False **kwargs)

# %%
data = df.query('Club == "Manchester City"')
long_name_age = data.loc[:, ['FullName', 'Age']]
long_name_age
# OR 
#data = df.query('Club == "Manchester City"')[["FullName", "Age"]]
#data
# Out:
#                              FullName  Age
# 5                     Kevin De Bruyne   30
# 19          Ederson Santana de Moraes   27
# 29                    Raheem Sterling   26
# 43       Rúben Santos Gato Alves Dias   24
# 59         Rodrigo Hernández Cascante   25
# 61                       Riyad Mahrez   30
# 64          João Pedro Cavaco Cancelo   27
# 65                    Aymeric Laporte   27
# 67     Bernardo Mota Carvalho e Silva   26
# 79                     İlkay Gündoğan   30
# 82                        Kyle Walker   31
# 102                        Phil Foden   21
# 121                     Jack Grealish   25
# 141                       John Stones   27
# 153                Fernando Luiz Rosa   36
# 179         Gabriel Fernando de Jesus   24
# 205              Ferran Torres García   21
# 491               Oleksandr Zinchenko   24
# 852                        Nathan Aké   26
# 863                      Zack Steffen   26
# 7774                     Scott Carson   35
# ...

# %% [markdown]
# Filter out the players who are players of Liverpool club and who are from Brazil
# and store them in the variable liverpool_brazil
# #Use the AND condition with filtering Or use the .query() method to filter out the players who
# are from the club 'Liverpool' and who are from Brazil
# syntax => df.query(expr, inplace=False, and **kwargs)

# %%
liverpool_brazil = df.query('Club == "Liverpool" and Nationality == "Brazil"')
liverpool_brazil
# Out:
#            ID              Name                             FullName  Age  \
# 21     212831           Alisson                Alisson Ramses Becker   28
# 68     209499           Fabinho               Fábio Henrique Tavares   27
# 69     201942   Roberto Firmino  Roberto Firmino Barbosa de Oliveira   29
# 17153  259430  Marcelo Pitaluga                     Marcelo Pitaluga   18
#
#        Height  Weight                                          PhotoUrl  \
# 21        191      91  https://cdn.sofifa.com/players/212/831/22_60.png
# 68        188      78  https://cdn.sofifa.com/players/209/499/22_60.png
# 69        181      76  https://cdn.sofifa.com/players/201/942/22_60.png
# 17153     191      78  https://cdn.sofifa.com/players/259/430/22_60.png
#
#       Nationality  Overall  Potential  ...  LMRating  CMRating  RMRating  \
# 21         Brazil       89         90  ...        41        43        41
# 68         Brazil       86         88  ...        80        84        80
# ...

# %% [markdown]
# How many players are there who have either mentality_aggression > 91 or power_stamina < 80
# #You can use the | operator (or) or the or keyword to filter out the players who have either mentality_aggression > 91 or power_stamina < 80. Here's an example of how to use the | operator:

# %%
mentality_aggression = df.query('Aggression > 91 or Stamina < 80')
mentality_aggression
# Out:
#            ID               Name                      FullName  Age  Height  \
# 0      158023           L. Messi                  Lionel Messi   34     170
# 1      188545     R. Lewandowski            Robert Lewandowski   32     185
# 2       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro   36     187
# 4      200389           J. Oblak                     Jan Oblak   28     188
# 7      215914           N. Kanté                  N'Golo Kanté   30     168
# ...       ...                ...                           ...  ...     ...
# 19255  262759           S. Black                 Stephen Black   19     180
# 19256  250978            Ma Zhen                       Zhen Ma   23     196
# 19257  261985         Yang Haoyu                    Haoyu Yang   20     183
# 19258  261977           He Siwei                      Siwei He   20     174
# 19259  261932      Chen Guoliang                 Guoliang Chen   22     186
#
# ...

# %% [markdown]
# Select all players from France who have either mentality_aggression > 91 or power_stamina < 80
# and store the filtered data in the variable france_player
# #Use help from the previous question. It is almost the same with slightly different conditions

# %%
france_player = df.query('Nationality == "France"  and (Aggression > 91 or Stamina <80)')
france_player
# Out:
#            ID        Name        FullName  Age  Height  Weight  \
# 7      215914    N. Kanté    N'Golo Kanté   30     168      70
# 13     165153  K. Benzema   Karim Benzema   33     185      81
# 36     195864    P. Pogba      Paul Pogba   28     191      84
# 45     167948   H. Lloris     Hugo Lloris   34     188      82
# 49     201535   R. Varane  Raphaël Varane   28     191      81
# ...       ...         ...             ...  ...     ...     ...
# 18313  263276     S. Goma     Steven Goma   19     183      73
# 18327  264501  I. Hamache   Ilyes Hamache   18     172      68
# 18388  263425  A. Delphis  Adrien Delphis   18     178      68
# 18658  233645  B. Nkololo    Béni Nkololo   24     186      75
# 18830  263712   M. Mastil   Melvin Mastil   21     196      92
#
#                                                PhotoUrl Nationality  Overall  \
# 7      https://cdn.sofifa.com/players/215/914/22_60.png      France       90
# ...

# %%
france_players_only = df.query('Nationality == "France"')
france_players_only
# Out:
#            ID        Name        FullName  Age  Height  Weight  \
# 3      231747   K. Mbappé   Kylian Mbappé   22     182      73
# 7      215914    N. Kanté    N'Golo Kanté   30     168      70
# 13     165153  K. Benzema   Karim Benzema   33     185      81
# 36     195864    P. Pogba      Paul Pogba   28     191      84
# 45     167948   H. Lloris     Hugo Lloris   34     188      82
# ...       ...         ...             ...  ...     ...     ...
# 18313  263276     S. Goma     Steven Goma   19     183      73
# 18327  264501  I. Hamache   Ilyes Hamache   18     172      68
# 18388  263425  A. Delphis  Adrien Delphis   18     178      68
# 18658  233645  B. Nkololo    Béni Nkololo   24     186      75
# 18830  263712   M. Mastil   Melvin Mastil   21     196      92
#
#                                                PhotoUrl Nationality  Overall  \
# 3      https://cdn.sofifa.com/players/231/747/22_60.png      France       91
# ...

# %% [markdown]
# How many players have Left foot as their preferred_foot, also print their short_name,age and preferred_foot
# Use conditioning to filter out all players with 'Left' as preferred_foot then get the columns ['short_name','age','preferred_foot'] only
# syntax => df.query(expr, inplace=False, **kwargs)
# or df.query(expr)[[ **kwargs]]

# %%
preferred_foot = df.query('PreferredFoot == "Left"')[["Name", "Age"]]
print(preferred_foot)
print()
preferred_foot.count()
# Out:
#               Name  Age
# 0         L. Messi   34
# 14     T. Courtois   29
# 18        M. Salah   29
# 19         Ederson   27
# 22       R. Lukaku   28
# ...            ...  ...
# 19219     S. Mandi   19
# 19230     N. Rabha   24
# 19234    D. Bhagat   22
# 19242     R. Mahon   18
# 19254   F. Emmings   17
#
# [4590 rows x 2 columns]
# Name    4590
# Age     4590
# dtype: int64

# %% [markdown]
# Create a visual to display all the left foot players and their worth using ValueEUR

# %%
dat = df.query('PreferredFoot == "Left"')
value_of_preferred_left_foot = dat.loc[:, ["ValueEUR"]]
value_of_preferred_left_foot
import matplotlib.pyplot as plt
value_of_preferred_left_foot.hist()
plt.show()
import seaborn as sb
#sb.histplot(value_of_preferred_left_foot['ValueEUR'], kde= True, bins= 15)
#sb.barplot(x='PreferredFoot', y='ValueEUR', data= df)

# %%
# Create a visual to display the Preferredfoot players and their worth using ValueEUR
sb.barplot(x='PreferredFoot', y='ValueEUR', data= df)
# Out:
# <Axes: xlabel='PreferredFoot', ylabel='ValueEUR'>

# %%
#Create a visual to display all the right foot players and their worth using ValueEUR
dat = df.query('PreferredFoot == "Right"')
value_of_preferred_Right_foot = dat.loc[:, ["ValueEUR"]]
value_of_preferred_Right_foot
value_of_preferred_left_foot.hist()
plt.show()

# %%
my_corr = france_player.select_dtypes(['number'])
my_corr.corr()
# Out:
#                  ID       Age    Height    Weight   Overall  Potential  \
# ID         1.000000 -0.856392 -0.020416 -0.211092 -0.562998   0.004595
# Age       -0.856392  1.000000  0.010886  0.209990  0.463169  -0.261000
# Height    -0.020416  0.010886  1.000000  0.774500 -0.003898  -0.005041
# Weight    -0.211092  0.209990  0.774500  1.000000  0.174461   0.010437
# Overall   -0.562998  0.463169 -0.003898  0.174461  1.000000   0.658527
# ...             ...       ...       ...       ...       ...        ...
# RWBRating -0.086289  0.085420 -0.254579 -0.186836  0.409270   0.318818
# LBRating  -0.076022  0.077206 -0.193283 -0.142481  0.380925   0.299944
# CBRating  -0.099972  0.100803  0.008947  0.034940  0.345872   0.260486
# RBRating  -0.076022  0.077206 -0.193283 -0.142481  0.380925   0.299944
# GKRating  -0.240725  0.175767  0.290642  0.291302  0.074528  -0.026536
#
#              Growth  TotalStats  BaseStats  ValueEUR  ...  LMRating  CMRating  \
# ...
